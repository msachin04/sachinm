# %% [markdown]
# <a href="https://colab.research.google.com/github/msachin04/sachinm/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Sachin")
a = 3.24
b = 2.76
print (a + b )
# Out:
# Sachin
# 6.0

# %% [markdown]
# **Introduction to Python**
